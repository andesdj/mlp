# %% [markdown]
# # Pandas cargar CSV General

# %%
import pandas as pd
import numpy as np
import os
mpath='../src/datasets/titanic'
pfile='titanic3.csv'
src=mpath+'/'+pfile
df=pd.read_csv(src, sep=',', header=0, )
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
import pandas as pd
import numpy as np
import os
mpath='../src/datasets/titanic'
mp2='../src/datasets/customer-churn-model'
pfile='titanic3.csv'
pfile2='Customer Churn Model.txt'
src=mpath+'/'+pfile
src2=mp2+'/'+pfile2
df=pd.read_csv(src, sep=',', header=0, )
#df.head()
df2=pd.read_csv(src2, sep=',', header=0, )
df2.head()
# Leer los nombres de las columnas


#df2.columns.values
# Out:
#   Column_Names
# 0            A
# 1            B
# 2            C
# 3            D
# 4            E

# %%
#Cambiar los nombres de las columnas del DF2 Se obtienen, se vuelven una lista y spuede leer el archiv nuevamente => DF2
mpc='../src/datasets/customer-churn-model'
pfilec='Customer Churn Columns.csv'
srcc=mpc+'/'+pfilec
dfc=pd.read_csv(srcc, sep=',', header=0, )
#Obtener en formato lista los nombres de las columnas
dfc_list=dfc['Column_Names'].tolist()
dfc_list
#Se omite la cabecera que se tiene 
df2=pd.read_csv(src2, sep=',', header=0, names=dfc_list)
df2.head()
# Out:
#     A    B    C         D    E    F   G      H    I      J  ...    L      M  \
# 0  KS  128  415  382-4657   no  yes  25  265.1  110  45.07  ...   99  16.78
# 1  OH  107  415  371-7191   no  yes  26  161.6  123  27.47  ...  103  16.62
# 2  NJ  137  415  358-1921   no   no   0  243.4  114  41.38  ...  110  10.30
# 3  OH   84  408  375-9999  yes   no   0  299.4   71  50.90  ...   88   5.26
# 4  OK   75  415  330-6626  yes   no   0  166.7  113  28.34  ...  122  12.61
#
#        N    O      P     Q  R     S  T       U
# 0  244.7   91  11.01  10.0  3  2.70  1  False.
# 1  254.4  103  11.45  13.7  3  3.70  1  False.
# 2  162.6  104   7.32  12.2  5  3.29  0  False.
# 3  196.9   89   8.86   6.6  7  1.78  2  False.
# 4  186.9  121   8.41  10.1  3  2.73  3  False.
#
# [5 rows x 21 columns]
