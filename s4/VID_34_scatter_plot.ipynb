# %%
#MAgic plot en la misma celda
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
mpath='../src/datasets/customer-churn-model'
pfile='Customer Churn Model.txt'
src=mpath+'/'+pfile
data=pd.read_csv(src, sep=',', header=0, )
data.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# 3              0     299.4         71       50.90  ...         88        5.26
# 4              0     166.7        113       28.34  ...        122       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# ...

# %% [markdown]
# ### Scatter plot
# ##### Guardar el Plot
# * savefig(path='RUTA DE GUARDAR IMAGEN.jpeg')

# %%
data.plot(kind='scatter', x='Day Mins', y='Day Charge')
data.plot(kind='scatter', y='VMail Message' , x='Area Code')

# %%
data.plot(kind='scatter', x='VMail Message' , y='Day Charge')

# %%
data.plot(kind='scatter', x='Night Mins', y='Night Charge')

# %%
figure,axs=plt.subplots(2,2,  sharey=True, sharex=True)

# %%
figure,axs=plt.subplots(2,2,  sharey=True, sharex=True)
data.plot(kind='scatter', x='Day Mins', y='Day Charge', ax=axs[0][0])
data.plot(kind='scatter', x='Night Mins', y='Night Charge', ax=axs[0][1])
data.plot(kind='scatter', x='Day Calls', y='Day Charge', ax=axs[1][0])
data.plot(kind='scatter', x='Night Calls', y='Night Charge', ax=axs[1][1])

# %% [markdown]
# ## Regla de sturges:
# #### Define cuantos bloques deben obtenerse en un histograma para su correcta lectura
# + Cuantas divisiones se hace el Histograma
# * k=int(np.ceil(1+np.log2(Tamano Muestra)))

# %%
# Obtener el largo de los campos para calcular con la regla de Sturges
data.describe

k=int(np.ceil(1+np.log2(3333)))

plt.hist(data['Day Calls'], bins=k)
plt.xlabel('Número de llamadas al día')
plt.ylabel('Frecuencia')
plt.title('Histograma de número de llamadas al día')
# Out:
# Text(0.5, 1.0, 'Histograma de número de llamadas al día')

# %%
#Diagrama de Caja de BIGOTES BOX PLOT
plt.boxplot(data['Day Calls'])
plt.ylabel('Numero de llamadas diarias')
data['Day Calls'].describe()


#114 -87 Rango intercuartilico, Tamaño de la caja: 27
# Los Bigotes se ponen a 1.5 el tamaño de este rango intercuartilico IQR
# Bigote inferior q(.25)-1.5*IQR 
# Bigote Superior q(.75)+1.5*IQR
# Out:
# count    3333.000000
# mean      100.435644
# std        20.069084
# min         0.000000
# 25%        87.000000
# 50%       101.000000
# 75%       114.000000
# max       165.000000
# Name: Day Calls, dtype: float64

# %% [markdown]
# * count    3333.000000
# * mean      100.435644
# * std        20.069084
# * min         0.000000
# * 25%        87.000000
# * 50%       101.000000
# * 75%       114.000000
# * max       165.000000
# * Name: Day Calls, dtype: float64
# #### Calcular diagrama de Bigotes
# * Q  25%: 87
# *  Q 75%: 114
# * 114 -87 Rango intercuartilico, Tamaño de la caja: 27
# * Los Bigotes se ponen a 1.5 el tamaño de este rango intercuartilico IQR
# * Bigote inferior q(.25)-1.5*IQR
# * Bigote Superior q(.75)+1.5*IQR
#
#
# * Todo lo que este fuera de los Bigotes Arriba y Abajo son lso Outliers se representan copn bolitas

# %%
#Diagrama de Caja de BIGOTES BOX PLOT
plt.boxplot(data[['Day Calls','Night Calls']])
plt.ylabel('Numero de llamadas diarias')
data['Day Calls'].describe().
# Out:
# count    3333.000000
# mean      100.435644
# std        20.069084
# min         0.000000
# 25%        87.000000
# 50%       101.000000
# 75%       114.000000
# max       165.000000
# Name: Day Calls, dtype: float64
