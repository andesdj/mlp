# %% [markdown]
# # Resumen de los datos: Dimensiones y estructuras

# %%
import pandas as pd
import os
path='C:/Users/root/mlp/udemy/src/datasets/titanic'
mainpath='../src/datasets/titanic/'
filename='titanic3.csv'
fullpath=mainpath+filename

# %%
data=pd.read_csv(fullpath)
#Los primeros
data.head()
#los ultimos
data.tail()
 # Obtener la forma del Dataset
data.shape
#Obtener nombre de las columas
data.columns.values
# Out:
# array(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch',
#        'ticket', 'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype=object)

# %% [markdown]
# # Obtener estadisticos básicos

# %%
#se puede saber cuantos datos son nulos
data.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
#Obtener el tipo de dato que existe
data.dtypes
# Out:
# pclass         int64
# survived       int64
# name          object
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %%
#Comprobar cuantos datos están nulos del dataset}
#Ravel construye un unico array de datos en caso de ser multilineal y lo permiote sumar
pd.isnull(data['body']).values.ravel().sum()
# Out:
# 1188

# %%
pd.notnull(data['body']).values.ravel().sum()
# Out:
# 121

# %% [markdown]
# ### Los valores que faltan en un Dataset pueden ser por dos razones
# * 1 Extracción de los datos (Valores faltantes a incompatibilidades
#     -Se puede hacer un mejor scrapping para optimizar
# * 2 Por recolección de los datos

# %% [markdown]
# ## Borrado de valores que faltan

# %%
#Borrar las filas con NAN 
#axis=0 borraria toda la fila, 
#axis=1 borra la columna 
#how:  = all= si todas estan Nan
#any: Borra toda la fila si alguna tiene algun NaN con cualquier nan BORRA TODO!
#
data.dropna(axis=0, how='all')
data2=data
data2.dropna(axis=0, how='any')
# Out:
# Empty DataFrame
# Columns: [pclass, survived, name, sex, age, sibsp, parch, ticket, fare, cabin, embarked, boat, body, home.dest]
# Index: []

# %% [markdown]
# # Computo de valores faltantes
# * Tratar de averiguar algun valor que falta sin tener que borrar los datos
# * Intentar escribir datos naN sustituyendo con 0

# %%
#Rellenar lo que falta con 0
data3=data
data3.fillna(0)
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
data4=data
data4.fillna('Desconocido')
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex          age  sibsp  parch  ticket     fare        cabin  \
# ...

# %%
# %config IPCompleter.greedy=True

# %%
data5=data
data5['home.dest']=data5['home.dest'].fillna('Desconocido')
#data5['age']=data5['age'].fillna(data['age'].mean())
data5
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
data5=data
data5['home.dest']=data5['home.dest'].fillna('Desconocido')
data5['age'][1291]
# Out:
# nan

# %% [markdown]
# # Forward and backward fill
# * ffill Toma el dato conocido anterior y llena lso NAN
# * backfill toma el valor siguiente y lllena el valor anterior que tenga NaN

# %%
data5['age']=data5['age'].fillna(method="ffill")
data5['age'][1291]
# Out:
# 47.0

# %%
#Reemplazar los datos con el promedio de edades Media
#La edad queda en valor float.  no int
pd.isnull(data5['age']).values.ravel().sum()
data5['age']=data5['age'].fillna(data5['age'].mean())
data5
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
data6=data
data6['age']=data6['age'].fillna(method='backfill')
data6.head(20)
data.head(20)
# Out:
#     pclass  survived                                               name  \
# 0        1         1                      Allen, Miss. Elisabeth Walton
# 1        1         1                     Allison, Master. Hudson Trevor
# 2        1         0                       Allison, Miss. Helen Loraine
# 3        1         0               Allison, Mr. Hudson Joshua Creighton
# 4        1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5        1         1                                Anderson, Mr. Harry
# 6        1         1                  Andrews, Miss. Kornelia Theodosia
# 7        1         0                             Andrews, Mr. Thomas Jr
# 8        1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9        1         0                            Artagaveytia, Mr. Ramon
# 10       1         0                             Astor, Col. John Jacob
# 11       1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %% [markdown]
# # Variables Dummy

# %%
data_sex=pd.get_dummies(data['sex'], prefix="sex")
data_sex.tail(20)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\platzi\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sex'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-3ae5bf4e0439> in <module>
# ...

# %%
#Dumificacion de variables : Convertir una  categoría a un conjunto de variables.
d_sex=pd.get_dummies(data['sex'], prefix='sex')
d_sex.head(20)
d_sex['sex_female'].sum()
column_name=data.columns.values.tolist()
column_name
#Borra la columna sex toda! axis=1 borra la columna
# 1 Despeus de obtener las variables Dummie generalmente se procede a eliminar la variabel original
# 2 Se Añade al dataset
data=data.drop(['sex'],axis=1)
data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\platzi\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sex'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-6a0c124a9c5d> in <module>
# ...

# %%
data=pd.concat([data,d_sex], axis=1)
data.head()
# Out:
#    pclass  survived                                             name      age  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  29.0000
# 1       1         1                   Allison, Master. Hudson Trevor   0.9167
# 2       1         0                     Allison, Miss. Helen Loraine   2.0000
# 3       1         0             Allison, Mr. Hudson Joshua Creighton  30.0000
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  25.0000
#
#    sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0      0      0   24160  211.3375       B5        S    2    NaN
# 1      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest  sex_female  sex_male
# ...

# %% [markdown]
# # Crear Funcion Para Construir las Dummies

# %%
import pandas as pd
import os
filename='titanic3.csv'
mainpath='../src/datasets/titanic/'
fullpath=mainpath+filename
df=pd.read_csv(fullpath)
def crearDummies(df,variable, drop=True):
    dummy=pd.get_dummies(df[variable],prefix=variable)
    if drop== True:
        df=df.drop(variable, axis=1)
    
    df=pd.concat([df,dummy], axis=1)
    print('creadas columnas Dummy para la variable: ', variable)
    return df

a=crearDummies(df,'sex', True)
a.head()
# Out:
# creadas columnas Dummy para la variable:  sex
#    pclass  survived                                             name      age  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  29.0000
# 1       1         1                   Allison, Master. Hudson Trevor   0.9167
# 2       1         0                     Allison, Miss. Helen Loraine   2.0000
# 3       1         0             Allison, Mr. Hudson Joshua Creighton  30.0000
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  25.0000
#
#    sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0      0      0   24160  211.3375       B5        S    2    NaN
# 1      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest  sex_female  sex_male
# ...
