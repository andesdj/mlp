# %%
from scipy.spatial import distance_matrix
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn import metrics
from sklearn.metrics import silhouette_samples, silhouette_score
from scipy.spatial.distance import cdist

# %matplotlib inline

# %%
x1= np.array([3,1,1,2,1,6,6,6,5,6,7,8,9,8,9,9,8])
x2= np.array([5,4,5,6,5,8,6,7,6,7,1,2,1,2,3,2,3])
X= np.array(list(zip(x1,x2))).reshape(len(x1),2)

# %%
plt.plot()
plt.xlim([0,10])
plt.ylim([0,10])
plt.title("Dataset a clasificar")
plt.xlabel("X")
plt.ylabel("Y")
plt.scatter(x1,x2)
plt.show()

# %%
# Numero de iteraciones (Cluster)  max
max_k=10
K=range(1,max_k+1)
ssw = []
color_palette = [plt.cm.Spectral(float(i)/max_k) for i in K]
centroid = [sum(X)/len(X) for i in K]
sst=sum(np.min(cdist(X,centroid, "euclidean"), axis=1))


for k in K:
    kmeanModel=KMeans(n_clusters= k).fit(X)
    centers = pd.DataFrame(kmeanModel.cluster_centers_)
    labels=kmeanModel.labels_
    
    
    ssw_k=sum(np.min(cdist(X,kmeanModel.cluster_centers_, "euclidean"), axis=1))
    ssw.append(ssw_k)
    label_color=[color_palette[i] for i in labels]

    ## Fabricar la silueta para cada cluster
    # NO hacemos silueta si: K=1 o K=len(X)
    if 1<k<len(X):
        # Crear un subplot de una fila y dos columnas
        fig, (axis1,axis2)= plt.subplots(1,2)
        fig.set_size_inches(20,8)
        
        #El primer subplot contendra la silueta que puede tener valores desde = -1 a  1
        # EN este caso , se controla que los valores estan entre -0.1 y 1
        axis1.set_xlim([-0.1,1])
        # el número de cluster a insertar determina el tamaño de cada barra
        
        # EL COEF de (Ncluster+1)*10 será el espacio en blanco que se dejará entre siluetas individuales
        # De daca cluser para separarlas
        FF=10
        axis1.set_ylim((0, len(X)+(k+1)*FF))
        silhouette_avg=silhouette_score(X,labels)
        print("* Para k = ",k, " el promedio de silueta es de: "+ str(silhouette_avg) )
        sample_silhouette_values =  silhouette_samples(X,labels)
        y_lower=10
        
        for i in range(k):
            # Agregamos la Silueta del cliuster k i-esimo ith
            ith_cluster_sv= sample_silhouette_values[labels == i]
            print("      - Para i = ", i+1, " La silueta cluster vale: ", np.mean(ith_cluster_sv))
            # ORdenar descendientemente las siluetas del cluster i-esimo
            
            
            ith_cluster_sv.sort()
            #Calcular donde ubicar la primera silueta en el eje vertical
            ith_cluster_size= ith_cluster_sv.shape[0]
            y_upper= y_lower+ith_cluster_size
            
            # Elegir el color del cluster
            color= color_palette[i]
            alph=0.7
            
            axis1.fill.betweenx(np.arange(y_lower,y_upper),
                               o, ith:cluster_sv, facecolor= color,alptha=alph)
# Out:
# * Para k =  2  el promedio de silueta es de: 0.6113424368705715
#       - Para i =  1  La silueta cluster vale:  0.49704450958269375
#       - Para i =  2  La silueta cluster vale:  0.7746251901389686
# * Para k =  3  el promedio de silueta es de: 0.7122079383287169
#       - Para i =  1  La silueta cluster vale:  0.7345257364682265
#       - Para i =  2  La silueta cluster vale:  0.6609508863896014
#       - Para i =  3  La silueta cluster vale:  0.7322200728725188
# * Para k =  4  el promedio de silueta es de: 0.6389948643127632
#       - Para i =  1  La silueta cluster vale:  0.7345257364682265
#       - Para i =  2  La silueta cluster vale:  0.24096929517637128
#       - Para i =  3  La silueta cluster vale:  0.654458796162702
#       - Para i =  4  La silueta cluster vale:  0.655666655624379
# * Para k =  5  el promedio de silueta es de: 0.42883912423017356
#       - Para i =  1  La silueta cluster vale:  0.1899052168375926
#       - Para i =  2  La silueta cluster vale:  0.24096929517637128
#       - Para i =  3  La silueta cluster vale:  0.654458796162702
#       - Para i =  4  La silueta cluster vale:  0.2698039021743969
#       - Para i =  5  La silueta cluster vale:  0.655666655624379
# * Para k =  6  el promedio de silueta es de: 0.39661977826122785
#       - Para i =  1  La silueta cluster vale:  0.42346712707864664
#       - Para i =  2  La silueta cluster vale:  0.655666655624379
#       - Para i =  3  La silueta cluster vale:  0.32882042637679976
#       - Para i =  4  La silueta cluster vale:  0.24096929517637128
#       - Para i =  5  La silueta cluster vale:  -0.09040786759303471
#       - Para i =  6  La silueta cluster vale:  0.5664789734180768
# * Para k =  7  el promedio de silueta es de: 0.37055812537654054
#       - Para i =  1  La silueta cluster vale:  0.24096929517637128
#       - Para i =  2  La silueta cluster vale:  0.14773975649110374
#       - Para i =  3  La silueta cluster vale:  0.32882042637679976
#       - Para i =  4  La silueta cluster vale:  0.655666655624379
#       - Para i =  5  La silueta cluster vale:  0.350084177231389
#       - Para i =  6  La silueta cluster vale:  0.5664789734180768
#       - Para i =  7  La silueta cluster vale:  0.0
# * Para k =  8  el promedio de silueta es de: 0.3846391401618392
#       - Para i =  1  La silueta cluster vale:  0.31256470041698214
#       - Para i =  2  La silueta cluster vale:  0.0
#       - Para i =  3  La silueta cluster vale:  0.5664789734180768
#       - Para i =  4  La silueta cluster vale:  0.6152265411044983
#       - Para i =  5  La silueta cluster vale:  0.32882042637679976
#       - Para i =  6  La silueta cluster vale:  0.3869086846339371
#       - Para i =  7  La silueta cluster vale:  0.0
#       - Para i =  8  La silueta cluster vale:  0.2751262658470836
# * Para k =  9  el promedio de silueta es de: 0.39932610787930767
#       - Para i =  1  La silueta cluster vale:  0.6152265411044983
#       - Para i =  2  La silueta cluster vale:  0.14644660940672627
#       - Para i =  3  La silueta cluster vale:  0.5664789734180768
#       - Para i =  4  La silueta cluster vale:  0.0
#       - Para i =  5  La silueta cluster vale:  0.0
#       - Para i =  6  La silueta cluster vale:  1.0
#       - Para i =  7  La silueta cluster vale:  0.0
#       - Para i =  8  La silueta cluster vale:  0.32882042637679976
#       - Para i =  9  La silueta cluster vale:  0.14644660940672627
# * Para k =  10  el promedio de silueta es de: 0.3363403864784915
#       - Para i =  1  La silueta cluster vale:  0.39052429175126996
#       - Para i =  2  La silueta cluster vale:  0.6152265411044983
#       - Para i =  3  La silueta cluster vale:  1.0
#       - Para i =  4  La silueta cluster vale:  0.0
#       - Para i =  5  La silueta cluster vale:  0.0
#       - Para i =  6  La silueta cluster vale:  0.20382042637679978
#       - Para i =  7  La silueta cluster vale:  0.0
#       - Para i =  8  La silueta cluster vale:  0.14644660940672627
#       - Para i =  9  La silueta cluster vale:  0.0
#       - Para i =  10  La silueta cluster vale:  0.0
