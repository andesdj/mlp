# %% [markdown]
# #  Distribucion Normal

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Valores que se usan, Media y Desviacion tipica
#La campana de Gauss... Media=0 es decir el pico en =0 y la Desv Estantar=1
n=10000
data= np.random.randn(n)
x= range(1,n+1)
y=data
plt.plot(x,y)

# %%
# %matplotlib inline
plt.hist(data)
# Out:
# (array([  27.,  182.,  954., 2345., 3075., 2301.,  882.,  200.,   30.,
#            4.]),
#  array([-3.55451335, -2.76493307, -1.97535278, -1.1857725 , -0.39619222,
#          0.39338806,  1.18296835,  1.97254863,  2.76212891,  3.55170919,
#          4.34128948]),
#  <a list of 10 Patch objects>)

# %%
plt.plot(sorted(data),x)

# %%
mu=5.5
sd=2.5
n=10000
# x= mu + SD*Z
data=mu+sd*np.random.randn(n)
plt.hist(data, bins=33)
# Out:
# (array([  4.,   4.,  10.,  29.,  34.,  41.,  89., 119., 204., 257., 348.,
#         451., 559., 670., 742., 803., 800., 803., 750., 711., 594., 549.,
#         381., 324., 249., 169., 124.,  81.,  39.,  27.,  16.,  11.,   8.]),
#  array([-3.05592180e+00, -2.54598930e+00, -2.03605680e+00, -1.52612431e+00,
#         -1.01619181e+00, -5.06259308e-01,  3.67319027e-03,  5.13605689e-01,
#          1.02353819e+00,  1.53347069e+00,  2.04340318e+00,  2.55333568e+00,
#          3.06326818e+00,  3.57320068e+00,  4.08313318e+00,  4.59306568e+00,
#          5.10299818e+00,  5.61293068e+00,  6.12286317e+00,  6.63279567e+00,
#          7.14272817e+00,  7.65266067e+00,  8.16259317e+00,  8.67252567e+00,
#          9.18245817e+00,  9.69239066e+00,  1.02023232e+01,  1.07122557e+01,
#          1.12221882e+01,  1.17321207e+01,  1.22420532e+01,  1.27519857e+01,
#          1.32619182e+01,  1.37718507e+01]),
#  <a list of 33 Patch objects>)

# %%
data=np.random.rand(2,4)
data
# Out:
# array([[0.96029131, 0.22412085, 0.95261322, 0.79414624],
#        [0.44560284, 0.07104618, 0.23855936, 0.28742774]])
