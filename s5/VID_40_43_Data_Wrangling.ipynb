# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
mpath='../src/datasets/customer-churn-model'
pfile='Customer Churn Model.txt'
src=mpath+'/'+pfile
data=pd.read_csv(src, sep=',', header=0, )
data.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# 3              0     299.4         71       50.90  ...         88        5.26
# 4              0     166.7        113       28.34  ...        122       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# ...

# %%
#Es un objeto de tipo Series NO ES UN DataFrame
account_length=data['Account Length']
#Para obtener  como si fuera un dataframe se pone en dos [[]]
subset=data[['Account Length','Phone', 'Eve Charge', 'Day Calls']]

# %%
#Extraer de forma mas sencillla los datos que se desean
desired_columns=['Account Length', 'Phone', 'Eve Charge', 'Day Calls', 'Night Calls']
subset= data[desired_columns]
subset
# Out:
#       Account Length     Phone  Eve Charge  Day Calls  Night Calls
# 0                128  382-4657       16.78        110           91
# 1                107  371-7191       16.62        123          103
# 2                137  358-1921       10.30        114          104
# 3                 84  375-9999        5.26         71           89
# 4                 75  330-6626       12.61        113          121
# ...              ...       ...         ...        ...          ...
# 3328             192  414-4276       18.32         77           83
# 3329              68  370-3271       13.04         57          123
# 3330              28  328-8230       24.55        109           91
# 3331             184  364-6381       13.57        105          137
# 3332              74  400-4344       22.60        113           77
#
# [3333 rows x 5 columns]

# %%
desired_columns=['Account Length', 'Vmail Message', 'Day Calls']
desired_columns
# Out:
# ['Account Length', 'Vmail Message', 'Day Calls']

# %%
all_columns_list= data.columns.values.tolist()
all_columns_list
# Out:
# ['State',
#  'Account Length',
#  'Area Code',
#  'Phone',
#  "Int'l Plan",
#  'VMail Plan',
#  'VMail Message',
#  'Day Mins',
#  'Day Calls',
#  'Day Charge',
#  'Eve Mins',
#  'Eve Calls',
#  'Eve Charge',
#  'Night Mins',
#  'Night Calls',
#  'Night Charge',
#  'Intl Mins',
#  'Intl Calls',
#  'Intl Charge',
#  'CustServ Calls',
#  'Churn?']

# %% [markdown]
# # Obtener las columnas complementarias

# %% [markdown]
# ##  Las que no estan en desired_columns,

# %%
# 
sublist= [x for x in all_columns_list if x not in desired_columns]
sublist
# Out:
# ['State',
#  'Area Code',
#  'Phone',
#  "Int'l Plan",
#  'VMail Plan',
#  'VMail Message',
#  'Day Mins',
#  'Day Charge',
#  'Eve Mins',
#  'Eve Calls',
#  'Eve Charge',
#  'Night Mins',
#  'Night Calls',
#  'Night Charge',
#  'Intl Mins',
#  'Intl Calls',
#  'Intl Charge',
#  'CustServ Calls',
#  'Churn?']

# %%
# seleccionar número de filas especifico
data[1:10]
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
# 5    AL             118        510  391-8027        yes         no
# 6    MA             121        510  355-9993         no        yes
# 7    MO             147        415  329-9001        yes         no
# 8    LA             117        408  335-4719         no         no
# 9    WV             141        415  330-8173        yes        yes
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# ...

# %%
# seleccionar número de filas especifico
data[3320:]
# Out:
#      State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 3320    GA             122        510  411-5677        yes         no
# 3321    VT              60        415  400-2738         no         no
# 3322    MD              62        408  409-1856         no         no
# 3323    IN             117        415  362-5899         no         no
# 3324    WV             159        415  377-1164         no         no
# 3325    OH              78        408  368-8555         no         no
# 3326    OH              96        415  347-6812         no         no
# 3327    SC              79        415  348-3830         no         no
# 3328    AZ             192        415  414-4276         no        yes
# 3329    WV              68        415  370-3271         no         no
# 3330    RI              28        510  328-8230         no         no
# 3331    CT             184        510  364-6381        yes         no
# ...

# %%
# Filtrrar usuarios Total mins >500
data1=data[data['Day Mins']>200]
data1
# Out:
#      State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0       KS             128        415  382-4657         no        yes
# 2       NJ             137        415  358-1921         no         no
# 3       OH              84        408  375-9999        yes         no
# 5       AL             118        510  391-8027        yes         no
# 6       MA             121        510  355-9993         no        yes
# ...    ...             ...        ...       ...        ...        ...
# 3312    SC             181        408  406-6304         no         no
# 3322    MD              62        408  409-1856         no         no
# 3329    WV              68        415  370-3271         no         no
# 3331    CT             184        510  364-6381        yes         no
# 3332    TN              74        415  400-4344         no        yes
#
#       VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  \
# ...

# %%
#Filtro usuarios Nueva York NY  AND --> &     OR --> | 
data2=data[data['State']=='NY']
data2
# Out:
#      State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 15      NY             161        415  351-7269         no         no
# 77      NY             144        408  360-1171         no         no
# 136     NY              75        415  374-8525         no        yes
# 182     NY              67        408  405-2888         no        yes
# 186     NY             106        408  422-1471         no         no
# ...    ...             ...        ...       ...        ...        ...
# 3219    NY             150        415  421-6268         no        yes
# 3227    NY             209        415  369-8703         no         no
# 3257    NY             171        415  412-6245         no         no
# 3275    NY             120        510  405-5083         no        yes
# 3310    NY              94        415  363-1123         no         no
#
#       VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  \
# ...

# %%
data3=data[(data['State']=='NY') & (data['Day Mins']>280)]
data3.shape
# Out:
# (4, 21)

# %%
data4=data[(data['State']=='NY') | (data['Day Mins']>300)]
data4.shape
# Out:
# (124, 21)

# %%
data5=data[(data['Day Calls']<data['Night Calls'])]
data5.shape
# Out:
# (1626, 21)

# %%
data5=data[(data['Day Mins']<data['Night Mins'])]
data5.shape
# Out:
# (2051, 21)

# %%
subset_f_50= data[['Day Mins', 'Night Mins', 'Account Length']]
subset_f_50
# Out:
#       Day Mins  Night Mins  Account Length
# 0        265.1       244.7             128
# 1        161.6       254.4             107
# 2        243.4       162.6             137
# 3        299.4       196.9              84
# 4        166.7       186.9              75
# ...        ...         ...             ...
# 3328     156.2       279.1             192
# 3329     231.1       191.3              68
# 3330     180.8       191.9              28
# 3331     213.8       139.2             184
# 3332     234.4       241.4              74
#
# [3333 rows x 3 columns]

# %%
#Primeras 10 filas, columnas de la 3 a la 6
#data.iloc[filas, columnas]
data.iloc[1:10, 3:6]
# Out:
#       Phone Int'l Plan VMail Plan
# 1  371-7191         no        yes
# 2  358-1921         no         no
# 3  375-9999        yes         no
# 4  330-6626        yes         no
# 5  391-8027        yes         no
# 6  355-9993         no        yes
# 7  329-9001        yes         no
# 8  335-4719         no         no
# 9  330-8173        yes        yes

# %%
#Todas las filas columas de la 3 a la 6
data.iloc[:,3:6]
# Out:
#          Phone Int'l Plan VMail Plan
# 0     382-4657         no        yes
# 1     371-7191         no        yes
# 2     358-1921         no         no
# 3     375-9999        yes         no
# 4     330-6626        yes         no
# ...        ...        ...        ...
# 3328  414-4276         no        yes
# 3329  370-3271         no         no
# 3330  328-8230         no         no
# 3331  364-6381        yes         no
# 3332  400-4344         no        yes
#
# [3333 rows x 3 columns]

# %%
#primeras 10 filas columnas 2,5,7
data.iloc[1:10,[2,5,7]]
# Out:
#    Area Code VMail Plan  Day Mins
# 1        415        yes     161.6
# 2        415         no     243.4
# 3        408         no     299.4
# 4        415         no     166.7
# 5        510         no     223.4
# 6        510        yes     218.2
# 7        415         no     157.0
# 8        408         no     184.5
# 9        415        yes     258.6

# %%
#primeras 10 filas columnas 2,5,7
data.iloc[1:10,[2,5,7]]

# %%
#LOC: Basado en etiquetas
# iLOC Basado en Posicion
data.loc[1:10,['State', 'Phone']]
# Out:
#    State     Phone
# 1     OH  371-7191
# 2     NJ  358-1921
# 3     OH  375-9999
# 4     OK  330-6626
# 5     AL  391-8027
# 6     MA  355-9993
# 7     MO  329-9001
# 8     LA  335-4719
# 9     WV  330-8173
# 10    IN  329-6603

# %%
#Crear una nueva Columna
data['Total Mins']=data['Day Mins']+data['Night Mins']+data['Eve Mins']
data
# Out:
#      State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0       KS             128        415  382-4657         no        yes
# 1       OH             107        415  371-7191         no        yes
# 2       NJ             137        415  358-1921         no         no
# 3       OH              84        408  375-9999        yes         no
# 4       OK              75        415  330-6626        yes         no
# ...    ...             ...        ...       ...        ...        ...
# 3328    AZ             192        415  414-4276         no        yes
# 3329    WV              68        415  370-3271         no         no
# 3330    RI              28        510  328-8230         no         no
# 3331    CT             184        510  364-6381        yes         no
# 3332    TN              74        415  400-4344         no        yes
#
#       VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Charge  \
# ...

# %%
data['Total Calls']= data['Day Calls']+data['Night Calls']+data['Eve Calls']
data.shape
# Out:
# (3333, 23)
