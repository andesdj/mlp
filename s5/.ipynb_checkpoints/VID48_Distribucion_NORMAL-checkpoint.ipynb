# %% [markdown]
# #  Distribucion Normal

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Valores que se usan, Media y Desviacion tipica
#La campana de Gauss... Media=0 es decir el pico en =0 y la Desv Estantar=1
n=1000000
data= np.random.randn(n)
x= range(1,1000001)
y=data
plt.plot(x,y)

# %%
# %matplotlib inline
plt.hist(data)
# Out:
# (array([1.27000e+02, 4.93200e+03, 5.99350e+04, 2.57988e+05, 4.01173e+05,
#         2.26339e+05, 4.60500e+04, 3.36700e+03, 8.80000e+01, 1.00000e+00]),
#  array([-4.67668753, -3.62237273, -2.56805793, -1.51374312, -0.45942832,
#          0.59488648,  1.64920128,  2.70351608,  3.75783088,  4.81214568,
#          5.86646048]),
#  <a list of 10 Patch objects>)

# %%
plt.plot(x,sorted(data))

# %%
mu=5.5
sd=2.5
data=mu+sd*np.random.randn(10000)
plt.hist(data)
# Out:
# (array([   5.,   34.,  331., 1142., 2444., 2957., 2026.,  838.,  195.,
#           28.]),
#  array([-4.72033222, -2.81636077, -0.91238932,  0.99158213,  2.89555359,
#          4.79952504,  6.70349649,  8.60746794, 10.51143939, 12.41541084,
#         14.3193823 ]),
#  <a list of 10 Patch objects>)

# %%
data=np.random.rand(2,4)
data
# Out:
# array([[0.22900388, 0.87944426, 0.75691791, 0.5978987 ],
#        [0.06428861, 0.53163811, 0.39508051, 0.1336556 ]])
